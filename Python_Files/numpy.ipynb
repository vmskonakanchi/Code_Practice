# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as pl

# %%
data = pd.read_csv(r"C:\Users\vmsko\OneDrive\Documents\GitHub\Code_Practice\Python_Files\NUOCUT PROJECTS\lsd_math_score_data.csv")

# %%
def show_bar():
    pl.figure(figsize=(20,20))
    pl.legend(['A simple line'])
    pl.bar(data['Drug_ppm'],data['Math_score'],color='green',animated=True)
    pl.show()
def show_pie():
    pl.pie(data['Drug_ppm'],explode=None)

# %%
show_pie()
