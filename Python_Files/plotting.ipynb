# %%
import pandas as pd
from matplotlib import pyplot as mp
from sklearn import linear_model as lr

# %%
csv = pd.read_csv(r"C:\Users\vmsko\OneDrive\Documents\GitHub\Code_Practice\Python_Files\NUOCUT PROJECTS\lsd_math_score_data.csv")
csv
# Out:
#    Time_delay  Drug_ppm  Math_score
# 0           5      1.17       78.93
# 1          15      2.97       58.20
# 2          30      3.26       67.47
# 3          60      4.69       37.47
# 4         120      5.83       45.65
# 5         240      6.00       32.92
# 6         480      6.41       29.97

# %%
csv["Time_delay"]
# Out:
# 0      5
# 1     15
# 2     30
# 3     60
# 4    120
# 5    240
# 6    480
# Name: Time_delay, dtype: int64

# %%
time = csv[["Time_delay"]]
time
# Out:
#    Time_delay
# 0           5
# 1          15
# 2          30
# 3          60
# 4         120
# 5         240
# 6         480

# %%
lsd = csv[["Drug_ppm"]]
lsd
# Out:
#    Drug_ppm
# 0      1.17
# 1      2.97
# 2      3.26
# 3      4.69
# 4      5.83
# 5      6.00
# 6      6.41

# %%
mp.figure(figsize=(20,10))
mp.grid()
mp.title('TITLE',fontsize = '100')
mp.xlabel('Time Delay',fontsize = '25')
mp.ylabel("LSD",fontsize='25')
mp.plot(csv["Drug_ppm"],csv["Math_score"])
mp.scatter(csv['Drug_ppm'],csv['Math_score'],color = 'red',s=100)
mp.show()

# %%
regr = lr.LinearRegression()

# %%
score = csv[["Math_score"]]
ppm = csv[["Drug_ppm"]]

# %%
regr.fit(ppm,score)
# Out:
# LinearRegression()

# %%
# Out:
# -9.009466415296783

# %%
mp.figure(figsize=(20,10))
mp.grid()
mp.title('TITLE',fontsize = '100')
mp.xlabel('Time Delay',fontsize = '25')
mp.ylabel("LSD",fontsize='25')
mp.plot(csv["Drug_ppm"],csv["Math_score"])
mp.plot(csv["Drug_ppm"],y)
mp.scatter(ppm,score,color = 'red',s=100)
mp.scatter(ppm,y,color = 'red',s=100)
mp.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2376/928514237.py in <module>
#       5 mp.ylabel("LSD",fontsize='25')
#       6 mp.plot(csv["Drug_ppm"],csv["Math_score"])
# ----> 7 mp.plot(csv["Drug_ppm"],y)
#       8 mp.scatter(ppm,score,color = 'red',s=100)
#       9 mp.scatter(ppm,y,color = 'red',s=100)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...
